# %% [markdown]
# ### Step 0
# Load the energy data from the file `Energy Indicators.xls`, which is a list of indicators of [energy supply and renewable electricity production](Energy%20Indicators.xls) from the [United Nations](http://unstats.un.org/unsd/environment/excel_file_tables/2013/Energy%20Indicators.xls) for the year 2013, and should be put into a DataFrame with the variable name of **energy**.
#
# Keep in mind that this is an Excel file, and not a comma separated values file. Also, make sure to exclude the footer and header information from the datafile. The first two columns are unneccessary, so you should get rid of them, and you should change the column labels so that the columns are:
#
# `['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']`
#
# Convert `Energy Supply` to gigajoules (there are 1,000,000 gigajoules in a petajoule). For all countries which have missing data (e.g. data with "...") make sure this is reflected as `np.NaN` values.
#
# Rename the following list of countries (for use in later questions):
#
# ```"Republic of Korea": "South Korea",
# "United States of America": "United States",
# "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
# "China, Hong Kong Special Administrative Region": "Hong Kong"```
#
# There are also several countries with numbers and/or parenthesis in their name. Be sure to remove these,
#
# e.g.
#
# `'Bolivia (Plurinational State of)'` should be `'Bolivia'`,
#
# `'Switzerland17'` should be `'Switzerland'`.

# %% [markdown]
# ### Step 1
# <br>
#
# Next, load the GDP data from the file `world_bank.csv`, which is a csv containing countries' GDP from 1960 to 2015 from [World Bank](http://data.worldbank.org/indicator/NY.GDP.MKTP.CD). Call this DataFrame **GDP**.
#
# Make sure to skip the header, and rename the following list of countries:
#
# ```"Korea, Rep.": "South Korea",
# "Iran, Islamic Rep.": "Iran",
# "Hong Kong SAR, China": "Hong Kong"```
#
# <br>

# %% [markdown]
# ### Step 2
# Finally, load the [Sciamgo Journal and Country Rank data for Energy Engineering and Power Technology](http://www.scimagojr.com/countryrank.php?category=2102) from the file `scimagojr-3.xlsx`, which ranks countries based on their journal contributions in the aforementioned area. Call this DataFrame **ScimEn**.

# %% [markdown]
# ### Step 3
# Join the three datasets: GDP, Energy, and ScimEn into a new dataset (using the intersection of country names). Use only the last 10 years (2006-2015) of GDP data and only the top 15 countries by Scimagojr 'Rank' (Rank 1 through 15).
#
# The index of this DataFrame should be the name of the country, and the columns should be ['Rank', 'Documents', 'Citable documents', 'Citations', 'Self-citations',
#        'Citations per document', 'H index', 'Energy Supply',
#        'Energy Supply per Capita', '% Renewable', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015'].
#
# *This step should yeild a DataFrame with 20 columns and 15 entries.*

# %% [markdown]
# ### Step 4
# The previous question joined three datasets then reduced this to just the top 15 entries. When you joined the datasets, but before you reduced this to the top 15 items, how many entries did you lose?
#
# *This step should yield a single number.*

# %% [markdown]
# ### Step 5
#
# #### Answer the following questions in the context of only the top 15 countries by Scimagojr Rank
#
#
# What is the average GDP over the last 10 years for each country? (exclude missing values from this calculation.)
#
# *This step should return a Series named `avgGDP` with 15 countries and their average GDP sorted in descending order.*

# %% [markdown]
# ### Step  6
# What is the mean `Energy Supply per Capita`?
#
# *This step should return a single number.*

# %% [markdown]
# ### Step 7
# What country has the maximum % Renewable and what is the percentage?
#
# *This step should return a tuple with the name of the country and the percentage.*

# %% [markdown]
# ### Step 8
# Create a new column that is the ratio of Self-Citations to Total Citations.
# What is the maximum value for this new column, and what country has the highest ratio?
#
# *This step should return a tuple with the name of the country and the ratio.*

# %% [markdown]
# ### Step 9
# Create a new column with a 1 if the country's % Renewable value is at or above the median for all countries in the top 15, and a 0 if the country's % Renewable value is below the median.
#
# *This step should return a series named `HighRenew` whose index is the country name sorted in ascending order of rank.*

# %% [markdown]
# ### Step 10
# Use the following dictionary to group the Countries by Continent, then create a dateframe that displays the sample size (the number of countries in each continent bin), and the sum, mean, and std deviation for the estimated population of each country.
#
# ```python
# ContinentDict  = {'China':'Asia',
#                   'United States':'North America',
#                   'Japan':'Asia',
#                   'United Kingdom':'Europe',
#                   'Russian Federation':'Europe',
#                   'Canada':'North America',
#                   'Germany':'Europe',
#                   'India':'Asia',
#                   'France':'Europe',
#                   'South Korea':'Asia',
#                   'Italy':'Europe',
#                   'Spain':'Europe',
#                   'Iran':'Asia',
#                   'Australia':'Australia',
#                   'Brazil':'South America'}
# ```
#
# *This function should return a DataFrame with index named Continent `['Asia', 'Australia', 'Europe', 'North America', 'South America']` and columns `['size', 'sum', 'mean', 'std']`*

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Step 0

# %% [markdown]
# Load the energy data from the file Energy Indicators.xls, which is a list of indicators of energy supply and renewable electricity production from the United Nations for the year 2013, and should be put into a DataFrame with the variable name of energy.

# %%
energy = pd.read_excel('Energy Indicators.xls',skiprows=17)

# %%
energy.drop(['Unnamed: 0','Unnamed: 1'],axis=1,inplace=True)

# %%
energy.head()
# Out:
#        Unnamed: 2 Petajoules Gigajoules           %
# 0     Afghanistan        321         10   78.669280
# 1         Albania        102         35  100.000000
# 2         Algeria       1959         51    0.551010
# 3  American Samoa        ...        ...    0.641026
# 4         Andorra          9        121   88.695650

# %%
energy = energy.rename(columns ={'Unnamed: 2': 'Country','Petajoules':'Energy Supply','Gigajoules':'Energy Supply per Capita','%':'% Renewable'})

# %%
energy.head()
# Out:
#           Country Energy Supply Energy Supply per Capita  % Renewable
# 0     Afghanistan           321                       10    78.669280
# 1         Albania           102                       35   100.000000
# 2         Algeria          1959                       51     0.551010
# 3  American Samoa           ...                      ...     0.641026
# 4         Andorra             9                      121    88.695650

# %%
energy.index[227:]
# Out:
# RangeIndex(start=227, stop=265, step=1)

# %%
df1 = energy.iloc[227:]

# %%
energy.drop(energy.index[227:],axis=0 , inplace = True)

# %%
energy.tail(5)
# Out:
#                        Country Energy Supply Energy Supply per Capita  \
# 222                   Viet Nam          2554                       28
# 223  Wallis and Futuna Islands             0                       26
# 224                      Yemen           344                       13
# 225                     Zambia           400                       26
# 226                   Zimbabwe           480                       32
#
#      % Renewable
# 222     45.32152
# 223      0.00000
# 224      0.00000
# 225     99.71467
# 226     52.53612

# %%
energy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 227 entries, 0 to 226
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Country                   227 non-null    object
#  1   Energy Supply             227 non-null    object
#  2   Energy Supply per Capita  227 non-null    object
#  3   % Renewable               227 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 8.9+ KB

# %%
energy['Energy Supply'].replace(to_replace ='...',value = np.nan,inplace=True)
energy['Energy Supply per Capita'].replace(to_replace='...',value = np.nan,inplace=True)

# %%
energy.isna().sum()
# Out:
# Country                     0
# Energy Supply               5
# Energy Supply per Capita    5
# % Renewable                 0
# dtype: int64

# %%
energy.astype({'Energy Supply':'float64','Energy Supply per Capita':'float64'})
# Out:
#                        Country  Energy Supply  Energy Supply per Capita  \
# 0                  Afghanistan          321.0                      10.0
# 1                      Albania          102.0                      35.0
# 2                      Algeria         1959.0                      51.0
# 3               American Samoa            NaN                       NaN
# 4                      Andorra            9.0                     121.0
# ..                         ...            ...                       ...
# 222                   Viet Nam         2554.0                      28.0
# 223  Wallis and Futuna Islands            0.0                      26.0
# 224                      Yemen          344.0                      13.0
# 225                     Zambia          400.0                      26.0
# 226                   Zimbabwe          480.0                      32.0
#
#      % Renewable
# 0      78.669280
# 1     100.000000
# 2       0.551010
# 3       0.641026
# ...

# %%
energy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 227 entries, 0 to 226
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Country                   227 non-null    object
#  1   Energy Supply             222 non-null    float64
#  2   Energy Supply per Capita  222 non-null    float64
#  3   % Renewable               227 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 8.9+ KB

# %%
energy['Country'].replace({'Republic of Korea': 'South Korea',
'United States of America20': 'United States',
'United Kingdom of Great Britain and Northern Ireland19': 'United Kingdom',
'China, Hong Kong Special Administrative Region3': 'Hong Kong','Bolivia (Plurinational State of)':'Bolivia','Venezuela (Bolivarian Republic of)':'Venezuela',
   'Indonesia8':'Indonesia' ,'Italy9':'Italy' ,'Sint Maarten (Dutch part)':'Sint Maarten','United Republic of Tanzania':'Tanzania',
              'Iran (Islamic Republic of)': 'Iran' ,'Switzerland17':'Switzerland' },inplace=True)

# %%
# energy['Country'].unique()

# %%
energy['Energy Supply'] = energy['Energy Supply']*1000000

# %%
energy.describe()
# Out:
#        Energy Supply  Energy Supply per Capita  % Renewable
# count   2.220000e+02                222.000000   227.000000
# mean    2.457982e+09                 90.666667    28.086077
# std     1.103915e+10                116.234887    31.903505
# min     0.000000e+00                  2.000000     0.000000
# 25%     3.300000e+07                 21.250000     0.022893
# 50%     1.895000e+08                 51.000000    14.814810
# 75%     9.962500e+08                117.750000    50.168620
# max     1.271910e+11                957.000000   100.000000

# %% [markdown]
# # Step 1

# %% [markdown]
# Next, load the GDP data from the file world_bank.csv, which is a csv containing countries' GDP from 1960 to 2015 from World Bank. Call this DataFrame GDP.

# %%
GDB = pd.read_csv('world_bank.csv', skiprows=4)
GDB.replace({"Korea, Rep.": "South Korea", 
                "Iran, Islamic Rep.": "Iran",
                "Hong Kong SAR, China": "Hong Kong"}, inplace=True)
GDB.rename(columns={'Country Name': 'Country'}, inplace=True)

# %%
# GDB=pd.melt(GDB,id_vars=['Country Name','Country Code','Indicator Code'],
#  value_vars = GDB.loc[:,'1960':'2015'] , var_name="Year",value_name='Energy Supply2')

# %%
GDB
# Out:
#               Country Country Code                            Indicator Name  \
# 0               Aruba          ABW  GDP at market prices (constant 2010 US$)
# 1             Andorra          AND  GDP at market prices (constant 2010 US$)
# 2         Afghanistan          AFG  GDP at market prices (constant 2010 US$)
# 3              Angola          AGO  GDP at market prices (constant 2010 US$)
# 4             Albania          ALB  GDP at market prices (constant 2010 US$)
# ..                ...          ...                                       ...
# 259       Yemen, Rep.          YEM  GDP at market prices (constant 2010 US$)
# 260      South Africa          ZAF  GDP at market prices (constant 2010 US$)
# 261  Congo, Dem. Rep.          COD  GDP at market prices (constant 2010 US$)
# 262            Zambia          ZMB  GDP at market prices (constant 2010 US$)
# 263          Zimbabwe          ZWE  GDP at market prices (constant 2010 US$)
#
# ...

# %%
GDB.isna().sum()
# Out:
# Country             0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960              145
# 1961              144
# 1962              144
# 1963              144
# 1964              144
# 1965              137
# 1966              132
# 1967              131
# 1968              127
# 1969              127
# 1970              118
# 1971              118
# 1972              118
# 1973              118
# 1974              117
# 1975              112
# 1976              111
# 1977              106
# 1978              106
# 1979              105
# 1980               92
# 1981               87
# 1982               83
# 1983               83
# 1984               79
# 1985               77
# 1986               74
# 1987               71
# 1988               68
# 1989               65
# 1990               52
# 1991               50
# 1992               47
# 1993               46
# 1994               44
# 1995               38
# 1996               38
# ...

# %%
GDB.shape
# Out:
# (264, 60)

# %% [markdown]
# # Step 2

# %% [markdown]
# Finally, load the Sciamgo Journal and Country Rank data for Energy Engineering and Power Technology from the file scimagojr-3.xlsx, which ranks countries based on their journal contributions in the aforementioned area. Call this DataFrame ScimEn.

# %%
ScimEn = pd.read_excel('scimagojr-3.xlsx')

# %%
ScimEn.head()
# Out:
#    Rank             Country  Documents  Citable documents  Citations  \
# 0     1               China     127050             126767     597237
# 1     2       United States      96661              94747     792274
# 2     3               Japan      30504              30287     223024
# 3     4      United Kingdom      20944              20357     206091
# 4     5  Russian Federation      18534              18301      34266
#
#    Self-citations  Citations per document  H index
# 0          411683                    4.70      138
# 1          265436                    8.20      230
# 2           61554                    7.31      134
# 3           37874                    9.84      139
# 4           12422                    1.85       57

# %%
# GDB_2 = GDB.loc[GDB['Year'].isin(['2006','2007','2008','2009','2010','2011','2012','2013','2014','2015'])]

# %%
# ScimEn.groupby(['Country','Rank']).head(15).reset_index(drop=True)

# %% [markdown]
# # Step 3

# %% [markdown]
# Join the three datasets: GDP, Energy, and ScimEn into a new dataset (using the intersection of country names). Use only the last 10 years (2006-2015) of GDP data and only the top 15 countries by Scimagojr 'Rank' (Rank 1 through 15).
#
# The index of this DataFrame should be the name of the country, and the columns should be ['Rank', 'Documents', 'Citable documents', 'Citations', 'Self-citations', 'Citations per document', 'H index', 'Energy Supply', 'Energy Supply per Capita', '% Renewable', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015'].

# %%
data = pd.merge(pd.merge(energy,GDB[['Country','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015']],on='Country'),
           (ScimEn.loc[ScimEn['Rank'].isin([i for i in range(1,16)])]),on = 'Country')

# %%
# from functools import reduce 
# df_3 = [ScimEn_2,GDB,energy]
# final_dfs = reduce(lambda right,left : pd.merge(right,left,on='Country', how='inner'),df_3)

# %%
# data.set_index('Country', inplace=True)
data
# Out:
#               Country  Energy Supply  Energy Supply per Capita  % Renewable  \
# 0              Brazil   1.214900e+10                      59.0    69.648030
# 1              Canada   1.043100e+10                     296.0    61.945430
# 2             Germany   1.326100e+10                     165.0    17.901530
# 3               India   3.319500e+10                      26.0    14.969080
# 4                Iran   9.172000e+09                     119.0     5.707721
# 5               Italy   6.530000e+09                     109.0    33.667230
# 6         South Korea   1.100700e+10                     221.0     2.279353
# 7  Russian Federation   3.070900e+10                     214.0    17.288680
# 8      United Kingdom   7.920000e+09                     124.0    10.600470
# 9       United States   9.083800e+10                     286.0    11.570980
#
#            2006          2007          2008          2009          2010  \
# ...

# %% [markdown]
# # Step 4

# %% [markdown]
# The previous question joined three datasets then reduced this to just the top 15 entries. When you joined the datasets, but before you reduced this to the top 15 items, how many entries did you lose?
#
# This step should yield a single number.

# %%
union = pd.merge(pd.merge(energy, GDB, on='Country', how='outer'), ScimEn, on='Country', how='outer')
intersect = pd.merge(pd.merge(energy, GDB, on='Country'), ScimEn, on='Country')
print(len(union)-len(intersect))
# Out:
# 182

# %% [markdown]
# # Step 5

# %% [markdown]
# Answer the following questions in the context of only the top 15 countries by Scimagojr Rank
# What is the average GDP over the last 10 years for each country? (exclude missing values from this calculation.)
# This step should return a Series named avgGDP with 15 countries and their average GDP sorted in descending order.

# %%
avgGDB =data.groupby(['Country'])['2006','2007','2008','2009','2010','2011','2012','2013','2014','2015'].mean().dropna()
avgGDB
# Out:
# C:\Users\Access\AppData\Local\Temp\ipykernel_3384\3407699749.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   avgGDB =data.groupby(['Country'])['2006','2007','2008','2009','2010','2011','2012','2013','2014','2015'].mean().dropna()
#                             2006          2007          2008          2009  \
# Country
# Brazil              1.845080e+12  1.957118e+12  2.056809e+12  2.054215e+12
# Canada              1.564469e+12  1.596740e+12  1.612713e+12  1.565145e+12
# Germany             3.332891e+12  3.441561e+12  3.478809e+12  3.283340e+12
# India               1.265894e+12  1.374865e+12  1.428361e+12  1.549483e+12
# Italy               2.202170e+12  2.234627e+12  2.211154e+12  2.089938e+12
# Russian Federation  1.385793e+12  1.504071e+12  1.583004e+12  1.459199e+12
# South Korea         9.410199e+11  9.924316e+11  1.020510e+12  1.027730e+12
# ...

# %% [markdown]
# # Step 6

# %% [markdown]
# What is the mean Energy Supply per Capita?
#
# This step should return a single number.

# %%
data['Energy Supply per Capita'].mean()
# Out:
# 161.9

# %% [markdown]
# # Step 7

# %% [markdown]
# What country has the maximum % Renewable and what is the percentage?
#
# This step should return a tuple with the name of the country and the percentage.

# %%
# for ind in data.index:
#     print(data['Country'][ind], data['% Renewable'][ind])

for ind, row in data.iterrows():
    print(row["Country"], np.max(row["% Renewable"]))
# Out:
# Brazil 69.64803
# Canada 61.94543
# Germany 17.90153
# India 14.96908
# Iran 5.707721
# Italy 33.66723
# South Korea 2.279353
# Russian Federation 17.28868
# United Kingdom 10.60047
# United States 11.57098

# %%
data['% Renewable'].argmax(), data['% Renewable'].max()
# Out:
# (0, 69.64803)

# %%
# def max_lists(data,value):
#     return(sorted(data , key =lambda x:max(x[:-1])))
     
# max((max_lists(max_country,-1)))

# %%
# for ind in df_2.index:
#     print((df_2['Country'][ind]),max(df_2['% Renewable']))
# lst=[]    
# for i in max_country :
#     lst.append(max(max_country))
# print(lst)

# %% [markdown]
# # Step 8

# %% [markdown]
# Create a new column that is the ratio of Self-Citations to Total Citations. What is the maximum value for this new column, and what country has the highest ratio?
#
# This step should return a tuple with the name of the country and the ratio.

# %%
data["Total citation"] = round((data['Self-citations'] / data['Citations'])*100,2)
result = data.sort_values("Total citation", ascending=False)
print(result.iloc[2])
# Out:
# Country                                    Iran
# Energy Supply                      9172000000.0
# Energy Supply per Capita                  119.0
# % Renewable                            5.707721
# 2006                         389552313541.27002
# 2007                        425064554419.086975
# 2008                        428990857822.094971
# HighRenew                                     0
# 2009                        438920754763.986023
# 2010                        467790215915.476013
# 2011                        485330901134.447998
# 2012                         453256899727.83197
# 2013                        444592553889.770996
# 2014                        463902735245.890015
# 2015                                        NaN
# Rank                                         13
# Documents                                  8896
# Citable documents                          8819
# Citations                                 57470
# Self-citations                            19125
# ...

# %%
(data['Total citation'].argmax(), data['Total citation'].max())
# Out:
# (7, 36.25)

# %%
data.head()
# Out:
#    Country  Energy Supply  Energy Supply per Capita  % Renewable  \
# 0   Brazil   1.214900e+10                      59.0    69.648030
# 1   Canada   1.043100e+10                     296.0    61.945430
# 2  Germany   1.326100e+10                     165.0    17.901530
# 3    India   3.319500e+10                      26.0    14.969080
# 4     Iran   9.172000e+09                     119.0     5.707721
#
#            2006          2007          2008  HighRenew          2009  \
# 0  1.845080e+12  1.957118e+12  2.056809e+12          1  2.054215e+12
# 1  1.564469e+12  1.596740e+12  1.612713e+12          1  1.565145e+12
# 2  3.332891e+12  3.441561e+12  3.478809e+12          1  3.283340e+12
# 3  1.265894e+12  1.374865e+12  1.428361e+12          0  1.549483e+12
# 4  3.895523e+11  4.250646e+11  4.289909e+11          0  4.389208e+11
#
#            2010  ...          2015  Rank  Documents  Citable documents  \
# 0  2.208872e+12  ...  2.319423e+12    15       8668               8596
# ...

# %% [markdown]
# # Step 9

# %% [markdown]
# Create a new column with a 1 if the country's % Renewable value is at or above the median for all countries in the top 15, and a 0 if the country's % Renewable value is below the median.
#
# This step should return a series named HighRenew whose index is the country name sorted in ascending order of rank.

# %%
 data['% Renewable'].median()
# Out:
# 16.12888

# %%
median = data['% Renewable'].median()
HighRenew=[]
for ind, row in data.iterrows():
    if row['% Renewable'] >= median:
        HighRenew.append(1)
    else:
        HighRenew.append(0)
HighRenew
# Out:
# [1, 1, 1, 0, 0, 1, 0, 1, 0, 0]

# %%
data.insert(7,'HighRenew',HighRenew)

# %%
data
# Out:
#               Country  Energy Supply  Energy Supply per Capita  % Renewable  \
# 0              Brazil   1.214900e+10                      59.0    69.648030
# 1              Canada   1.043100e+10                     296.0    61.945430
# 2             Germany   1.326100e+10                     165.0    17.901530
# 3               India   3.319500e+10                      26.0    14.969080
# 4                Iran   9.172000e+09                     119.0     5.707721
# 5               Italy   6.530000e+09                     109.0    33.667230
# 6         South Korea   1.100700e+10                     221.0     2.279353
# 7  Russian Federation   3.070900e+10                     214.0    17.288680
# 8      United Kingdom   7.920000e+09                     124.0    10.600470
# 9       United States   9.083800e+10                     286.0    11.570980
#
#            2006          2007          2008  HighRenew          2009  \
# ...

# %% [markdown]
# # Step 10

# %% [markdown]
# Use the following dictionary to group the Countries by Continent, then create a dateframe that displays the sample size (the number of countries in each continent bin), and the sum, mean, and std deviation for the estimated population of each country.
# This function should return a DataFrame with index named Continent ['Asia', 'Australia', 'Europe', 'North America', 'South America'] and columns ['size', 'sum', 'mean', 'std']

# %%
ContinentDict  = {'China':'Asia', 
                  'United States':'North America', 
                  'Japan':'Asia', 
                  'United Kingdom':'Europe', 
                  'Russian Federation':'Europe', 
                  'Canada':'North America', 
                  'Germany':'Europe', 
                  'India':'Asia',
                  'France':'Europe', 
                  'South Korea':'Asia', 
                  'Italy':'Europe', 
                  'Spain':'Europe', 
                  'Iran':'Asia',
                  'Australia':'Australia', 
                  'Brazil':'South America'}

# %%
df = pd.DataFrame(ContinentDict, index = range(len(ContinentDict))).drop_duplicates().T
df['country'] = df.index
df.rename(columns={0: 'continent'}, inplace=True)
df_gb = df.groupby('continent', as_index=False, sort=False).agg(','.join)

print(df_gb)
# Out:
#        continent                                            country
# 0           Asia                 China,Japan,India,South Korea,Iran
# 1  North America                               United States,Canada
# 2         Europe  United Kingdom,Russian Federation,Germany,Fran...
# 3      Australia                                          Australia
# 4  South America                                             Brazil

# %%
data
# Out:
#               Country  Energy Supply  Energy Supply per Capita  % Renewable  \
# 0              Brazil   1.214900e+10                      59.0    69.648030
# 1              Canada   1.043100e+10                     296.0    61.945430
# 2             Germany   1.326100e+10                     165.0    17.901530
# 3               India   3.319500e+10                      26.0    14.969080
# 4                Iran   9.172000e+09                     119.0     5.707721
# 5               Italy   6.530000e+09                     109.0    33.667230
# 6         South Korea   1.100700e+10                     221.0     2.279353
# 7  Russian Federation   3.070900e+10                     214.0    17.288680
# 8      United Kingdom   7.920000e+09                     124.0    10.600470
# 9       United States   9.083800e+10                     286.0    11.570980
#
#            2006          2007          2008  HighRenew          2009  \
# ...

# %%
groups = pd.DataFrame(columns = ['size', 'sum', 'mean', 'std'])
data['Estimate Population'] = data['Energy Supply'] / data['Energy Supply per Capita']
for group, frame in data.groupby(ContinentDict):
    groups.loc[group] = [len(frame), frame['Estimate Population'].sum(),frame['Estimate Population'].mean(),frame['Estimate Population'].std()]
print(groups)
# Out:
# Empty DataFrame
# Columns: [size, sum, mean, std]
# Index: []

# %%
data['Estimate Population'] = round(data['Energy Supply'] / data['Energy Supply per Capita']*100,2)

# %%
  
ContinentDict  = {'China':'Asia', 
                  'United States':'North America', 
                  'Japan':'Asia', 
                  'United Kingdom':'Europe', 
                  'Russian Federation':'Europe', 
                  'Canada':'North America', 
                  'Germany':'Europe', 
                  'India':'Asia',
                  'France':'Europe', 
                  'South Korea':'Asia', 
                  'Italy':'Europe', 
                  'Spain':'Europe', 
                  'Iran':'Asia',
                  'Australia':'Australia', 
                  'Brazil':'South America'}
data["Bins"] = pd.cut(data["% Renewable"], 5)

# %%
data['Continent'] = pd.Series(ContinentDict)

# %%
data
# Out:
#               Country  Energy Supply  Energy Supply per Capita  % Renewable  \
# 0              Brazil   1.214900e+10                      59.0    69.648030
# 1              Canada   1.043100e+10                     296.0    61.945430
# 2             Germany   1.326100e+10                     165.0    17.901530
# 3               India   3.319500e+10                      26.0    14.969080
# 4                Iran   9.172000e+09                     119.0     5.707721
# 5               Italy   6.530000e+09                     109.0    33.667230
# 6         South Korea   1.100700e+10                     221.0     2.279353
# 7  Russian Federation   3.070900e+10                     214.0    17.288680
# 8      United Kingdom   7.920000e+09                     124.0    10.600470
# 9       United States   9.083800e+10                     286.0    11.570980
#
#            2006          2007          2008  HighRenew          2009  \
# ...
